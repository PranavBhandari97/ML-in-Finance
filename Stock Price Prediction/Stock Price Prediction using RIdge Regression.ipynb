# %% [markdown]
# ## Importing the Libraries

# %%
import pandas as pd
import plotly.express as px
from copy import copy
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np
import plotly.figure_factory as ff
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from tensorflow import keras

# %% [markdown]
# ## Importing the Datasets

# %%
stock_price_df = pd.read_csv('stock.csv')
stock_price_df
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     2012-01-12   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     2012-01-13   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     2012-01-17   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     2012-01-18   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     2012-01-19   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  2020-08-05  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  2020-08-06  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  2020-08-07  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  2020-08-10  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# ...

# %%
stock_vol_df = pd.read_csv('stock_volume.csv')
stock_vol_df
# Out:
#             Date      AAPL        BA  ...     TSLA      GOOG       sp500
# 0     2012-01-12  53146800   3934500  ...   729300   3764400  4019890000
# 1     2012-01-13  56505400   4641100  ...  5500400   4631800  3692370000
# 2     2012-01-17  60724300   3700100  ...  4651600   3832800  4010490000
# 3     2012-01-18  69197800   4189500  ...  1260200   5544000  4096160000
# 4     2012-01-19  65434600   5397300  ...  1246300  12657800  4465890000
# ...          ...       ...       ...  ...      ...       ...         ...
# 2154  2020-08-05  30498000  46551000  ...  4978000   1979500  4732220000
# 2155  2020-08-06  50607200  32921600  ...  5992300   1995400  4267490000
# 2156  2020-08-07  49453300  19301600  ...  8883500   1576600  4104860000
# 2157  2020-08-10  53100900  35857700  ...  7522300   1289300  4318570000
# 2158  2020-08-11  46871100  60966900  ...  8356000   1452000  5087650000
#
# [2159 rows x 10 columns]

# %% [markdown]
# ### Sorting the datasets based on Dates

# %%
stock_price_df = stock_price_df.sort_values(by = ['Date'])
stock_price_df
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     2012-01-12   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     2012-01-13   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     2012-01-17   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     2012-01-18   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     2012-01-19   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  2020-08-05  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  2020-08-06  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  2020-08-07  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  2020-08-10  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# ...

# %%
stock_vol_df = stock_vol_df.sort_values(by = ['Date'])
stock_vol_df
# Out:
#             Date      AAPL        BA  ...     TSLA      GOOG       sp500
# 0     2012-01-12  53146800   3934500  ...   729300   3764400  4019890000
# 1     2012-01-13  56505400   4641100  ...  5500400   4631800  3692370000
# 2     2012-01-17  60724300   3700100  ...  4651600   3832800  4010490000
# 3     2012-01-18  69197800   4189500  ...  1260200   5544000  4096160000
# 4     2012-01-19  65434600   5397300  ...  1246300  12657800  4465890000
# ...          ...       ...       ...  ...      ...       ...         ...
# 2154  2020-08-05  30498000  46551000  ...  4978000   1979500  4732220000
# 2155  2020-08-06  50607200  32921600  ...  5992300   1995400  4267490000
# 2156  2020-08-07  49453300  19301600  ...  8883500   1576600  4104860000
# 2157  2020-08-10  53100900  35857700  ...  7522300   1289300  4318570000
# 2158  2020-08-11  46871100  60966900  ...  8356000   1452000  5087650000
#
# [2159 rows x 10 columns]

# %%
#Checking for Null values in Stock Prices
stock_price_df.isnull().sum()
# Out:
# Date     0
# AAPL     0
# BA       0
# T        0
# MGM      0
# AMZN     0
# IBM      0
# TSLA     0
# GOOG     0
# sp500    0
# dtype: int64

# %%
#Checking for Null values in Stock Volume data
stock_vol_df.isnull().sum()
# Out:
# Date     0
# AAPL     0
# BA       0
# T        0
# MGM      0
# AMZN     0
# IBM      0
# TSLA     0
# GOOG     0
# sp500    0
# dtype: int64

# %%
stock_price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2159 entries, 0 to 2158
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2159 non-null   object
#  1   AAPL    2159 non-null   float64
#  2   BA      2159 non-null   float64
#  3   T       2159 non-null   float64
#  4   MGM     2159 non-null   float64
#  5   AMZN    2159 non-null   float64
#  6   IBM     2159 non-null   float64
#  7   TSLA    2159 non-null   float64
#  8   GOOG    2159 non-null   float64
#  9   sp500   2159 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 185.5+ KB

# %%
stock_vol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2159 entries, 0 to 2158
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2159 non-null   object
#  1   AAPL    2159 non-null   int64
#  2   BA      2159 non-null   int64
#  3   T       2159 non-null   int64
#  4   MGM     2159 non-null   int64
#  5   AMZN    2159 non-null   int64
#  6   IBM     2159 non-null   int64
#  7   TSLA    2159 non-null   int64
#  8   GOOG    2159 non-null   int64
#  9   sp500   2159 non-null   int64
# dtypes: int64(9), object(1)
# memory usage: 185.5+ KB

# %%
stock_vol_df.describe()
# Out:
#                AAPL            BA  ...          GOOG         sp500
# count  2.159000e+03  2.159000e+03  ...  2.159000e+03  2.159000e+03
# mean   5.820332e+07  6.419916e+06  ...  2.498238e+06  3.680732e+09
# std    4.568141e+07  9.711873e+06  ...  1.928407e+06  8.622717e+08
# min    1.136200e+07  7.889000e+05  ...  7.900000e+03  1.248960e+09
# 25%    2.769930e+07  3.031850e+06  ...  1.325400e+06  3.211890e+09
# 50%    4.209420e+07  3.991000e+06  ...  1.813900e+06  3.526890e+09
# 75%    7.182480e+07  5.325900e+06  ...  3.245350e+06  3.933290e+09
# max    3.765300e+08  1.032128e+08  ...  2.497790e+07  9.044690e+09
#
# [8 rows x 9 columns]

# %%
stock_vol_df.describe()
# Out:
#                AAPL            BA  ...          GOOG         sp500
# count  2.159000e+03  2.159000e+03  ...  2.159000e+03  2.159000e+03
# mean   5.820332e+07  6.419916e+06  ...  2.498238e+06  3.680732e+09
# std    4.568141e+07  9.711873e+06  ...  1.928407e+06  8.622717e+08
# min    1.136200e+07  7.889000e+05  ...  7.900000e+03  1.248960e+09
# 25%    2.769930e+07  3.031850e+06  ...  1.325400e+06  3.211890e+09
# 50%    4.209420e+07  3.991000e+06  ...  1.813900e+06  3.526890e+09
# 75%    7.182480e+07  5.325900e+06  ...  3.245350e+06  3.933290e+09
# max    3.765300e+08  1.032128e+08  ...  2.497790e+07  9.044690e+09
#
# [8 rows x 9 columns]

# %%
stock_price_df.describe()
# Out:
#               AAPL           BA  ...         GOOG        sp500
# count  2159.000000  2159.000000  ...  2159.000000  2159.000000
# mean    140.819823   189.942700  ...   783.712512  2218.749554
# std      70.827601   103.678586  ...   334.448057   537.321727
# min      55.790001    67.239998  ...   278.481171  1278.040039
# 25%      89.165714   124.015000  ...   527.214416  1847.984985
# 50%     116.599998   142.419998  ...   737.599976  2106.629883
# 75%     175.019997   297.044998  ...  1079.744995  2705.810059
# max     455.609985   440.619995  ...  1568.489990  3386.149902
#
# [8 rows x 9 columns]

# %% [markdown]
# ### Creating function to Normalize and Visualize the Data

# %%
def normalize(df):
  x = df.copy()
  for i in x.columns[1:]:
    x[i] = x[i]/x[i][0]
  return x

# %%
def interactive_plot(df, title):
  fig = px.line(title = title)
  for i in df.columns[1:]:
    fig.add_scatter(x = df['Date'], y = df[i], name = i)
  fig.show()

# %%
interactive_plot(stock_price_df, 'Stock Prices(Raw)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b8ac914f-1fb5-477b-a3f0-65a49d27112a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b8ac914f-1fb5-477b-a3f0-65a49d27112a")) {
#                     Plotly.newPlot(
#                         'b8ac914f-1fb5-477b-a3f0-65a49d27112a',
# ...

# %%
interactive_plot(stock_price_df,'Stock Prices(Normalized)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="61d67f14-6c08-42c1-99af-c94e26db6d44" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("61d67f14-6c08-42c1-99af-c94e26db6d44")) {
#                     Plotly.newPlot(
#                         '61d67f14-6c08-42c1-99af-c94e26db6d44',
# ...

# %%
interactive_plot(stock_vol_df,'Stock Volumne(Raw)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6ad170a1-f3e0-40f5-9a5d-7563f6bb01a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6ad170a1-f3e0-40f5-9a5d-7563f6bb01a6")) {
#                     Plotly.newPlot(
#                         '6ad170a1-f3e0-40f5-9a5d-7563f6bb01a6',
# ...

# %%
interactive_plot(stock_vol_df,'Stock Volumne(Normalized)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f560ff1f-245c-4b0e-9d47-62fe9037de4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f560ff1f-245c-4b0e-9d47-62fe9037de4c")) {
#                     Plotly.newPlot(
#                         'f560ff1f-245c-4b0e-9d47-62fe9037de4c',
# ...

# %% [markdown]
# ## Preparing the Data for Model Training

# %%
#Creating a function to concatenate the date, stock price, and volume into one dataframe
def individual_stock(price_df, vol_df, name):
    return pd.DataFrame({'Date': price_df['Date'], 'Close': price_df[name], 'Volume': vol_df[name]})

# %%
#Creating a function so that target stock price today will be tomorrow's price 
def trading_window(data): 
  n = 1
  data['Target'] = data[['Close']].shift(-n) 
  return data

# %%
price_volume_df = individual_stock(stock_price_df, stock_vol_df, 'AAPL')
price_volume_df
# Out:
#             Date       Close    Volume
# 0     2012-01-12   60.198570  53146800
# 1     2012-01-13   59.972858  56505400
# 2     2012-01-17   60.671429  60724300
# 3     2012-01-18   61.301430  69197800
# 4     2012-01-19   61.107143  65434600
# ...          ...         ...       ...
# 2154  2020-08-05  440.250000  30498000
# 2155  2020-08-06  455.609985  50607200
# 2156  2020-08-07  444.450012  49453300
# 2157  2020-08-10  450.910004  53100900
# 2158  2020-08-11  437.500000  46871100
#
# [2159 rows x 3 columns]

# %%
price_volume_target_df = trading_window(price_volume_df)
price_volume_target_df
# Out:
#             Date       Close    Volume      Target
# 0     2012-01-12   60.198570  53146800   59.972858
# 1     2012-01-13   59.972858  56505400   60.671429
# 2     2012-01-17   60.671429  60724300   61.301430
# 3     2012-01-18   61.301430  69197800   61.107143
# 4     2012-01-19   61.107143  65434600   60.042858
# ...          ...         ...       ...         ...
# 2154  2020-08-05  440.250000  30498000  455.609985
# 2155  2020-08-06  455.609985  50607200  444.450012
# 2156  2020-08-07  444.450012  49453300  450.910004
# 2157  2020-08-10  450.910004  53100900  437.500000
# 2158  2020-08-11  437.500000  46871100         NaN
#
# [2159 rows x 4 columns]

# %%
#Removing the last row as it will be a null value
price_volume_target_df = price_volume_target_df[:-1]
price_volume_target_df
# Out:
#             Date       Close    Volume      Target
# 0     2012-01-12   60.198570  53146800   59.972858
# 1     2012-01-13   59.972858  56505400   60.671429
# 2     2012-01-17   60.671429  60724300   61.301430
# 3     2012-01-18   61.301430  69197800   61.107143
# 4     2012-01-19   61.107143  65434600   60.042858
# ...          ...         ...       ...         ...
# 2153  2020-08-04  438.660004  43267900  440.250000
# 2154  2020-08-05  440.250000  30498000  455.609985
# 2155  2020-08-06  455.609985  50607200  444.450012
# 2156  2020-08-07  444.450012  49453300  450.910004
# 2157  2020-08-10  450.910004  53100900  437.500000
#
# [2158 rows x 4 columns]

# %%
#Scaling the Data
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
price_volume_target_scaled_df = sc.fit_transform(price_volume_target_df.drop(columns = ['Date']))

# %%
price_volume_target_scaled_df
# Out:
# array([[0.01102638, 0.11442624, 0.01046185],
#        [0.01046185, 0.12362365, 0.01220906],
#        [0.01220906, 0.13517696, 0.01378478],
#        ...,
#        [1.        , 0.10747163, 0.97208751],
#        [0.97208751, 0.10431171, 0.98824476],
#        [0.98824476, 0.11430054, 0.95470465]])

# %%
price_volume_target_scaled_df.shape
# Out:
# (2158, 3)

# %%
#Creating the Dependent and Independent Variables
X = price_volume_target_scaled_df[:,:2]
y = price_volume_target_scaled_df[:,2:]

# %%
X.shape, y.shape
# Out:
# ((2158, 2), (2158, 1))

# %%
#Creating the Training and Testing Datasets
split = int(0.8 * len(X))
X_train = X[:split]
y_train = y[:split]
X_test = X[split:]
y_test = y[split:]

# %%
X_train.shape, y_train.shape
# Out:
# ((1726, 2), (1726, 1))

# %%
X_test.shape, y_test.shape
# Out:
# ((432, 2), (432, 1))

# %%
#Defining a data plotting function
def show_plot(data, title):
  plt.figure(figsize = (13, 5))
  plt.plot(data, linewidth = 3)
  plt.title(title)
  plt.grid()

show_plot(X_train, 'Training Data')
show_plot(X_test, 'Testing Data')

# %% [markdown]
# ## Building a Ridge Linear Regression Model

# %%
from sklearn.linear_model import Ridge
regression_model = Ridge(alpha = 0.5)
regression_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
#Testing the model and calculating its accuracy 
lr_accuracy = regression_model.score(X_test, y_test)
print("Linear Regression Score: ", lr_accuracy)
# Out:
# Linear Regression Score:  0.9842555843534463

# %%
#Making Predictions
predicted_prices = regression_model.predict(X)
predicted_prices
# Out:
# array([[0.01701331],
#        [0.01632429],
#        [0.01781879],
#        ...,
#        [0.96730444],
#        [0.94053721],
#        [0.95590144]])

# %%
Predicted = []
for i in predicted_prices:
  Predicted.append(i[0])

# %%
len(Predicted)
# Out:
# 2158

# %%
close = []
for i in price_volume_target_scaled_df:
  close.append(i[0])

# %%
df_predicted = price_volume_target_df[['Date']]
df_predicted
# Out:
#             Date
# 0     2012-01-12
# 1     2012-01-13
# 2     2012-01-17
# 3     2012-01-18
# 4     2012-01-19
# ...          ...
# 2153  2020-08-04
# 2154  2020-08-05
# 2155  2020-08-06
# 2156  2020-08-07
# 2157  2020-08-10
#
# [2158 rows x 1 columns]

# %%
df_predicted['Close'] = close
df_predicted
# Out:
#             Date     Close
# 0     2012-01-12  0.011026
# 1     2012-01-13  0.010462
# 2     2012-01-17  0.012209
# 3     2012-01-18  0.013785
# 4     2012-01-19  0.013299
# ...          ...       ...
# 2153  2020-08-04  0.957606
# 2154  2020-08-05  0.961583
# 2155  2020-08-06  1.000000
# 2156  2020-08-07  0.972088
# 2157  2020-08-10  0.988245
#
# [2158 rows x 2 columns]

# %%
df_predicted['Prediction'] = Predicted
df_predicted
# Out:
#             Date     Close  Prediction
# 0     2012-01-12  0.011026    0.017013
# 1     2012-01-13  0.010462    0.016324
# 2     2012-01-17  0.012209    0.017819
# 3     2012-01-18  0.013785    0.018963
# 4     2012-01-19  0.013299    0.018660
# ...          ...       ...         ...
# 2153  2020-08-04  0.957606    0.926894
# 2154  2020-08-05  0.961583    0.931272
# 2155  2020-08-06  1.000000    0.967304
# 2156  2020-08-07  0.972088    0.940537
# 2157  2020-08-10  0.988245    0.955901
#
# [2158 rows x 3 columns]

# %%
#Plotting the results
interactive_plot(df_predicted, "Original Vs. Prediction")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0195f77f-04f1-48f7-ab17-1fa5de890e00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0195f77f-04f1-48f7-ab17-1fa5de890e00")) {
#                     Plotly.newPlot(
#                         '0195f77f-04f1-48f7-ab17-1fa5de890e00',
# ...
